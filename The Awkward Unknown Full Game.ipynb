# %% [markdown]
# # THE AWKWARD UNKNOWN #

# %%
#the starting prompt of the game
print("The awkward is not unknown but, the unknown is awkward.")
print("-------------------------------------------------------------------------------------------------------------------")
print("Welcome to your awkward unknown, where every choice you make and every action you take, dictates your future and most \nimportantly, whether you survive or die trying.")
print("-------------------------------------------------------------------------------------------------------------------")
# Out:
# The awkward is not unknown but, the unknown is awkward.
# -------------------------------------------------------------------------------------------------------------------
# Welcome to your awkward unknown, where every choice you make and every action you take, dictates your future and most
# importantly, whether you survive or die trying.
# -------------------------------------------------------------------------------------------------------------------

# %%
import time #Adds a pause 

#Answer choices
answer_A = ["A", "a"]
answer_B = ["B", "b"]
answer_C = ["C", "c"]
yes = ["Y", "y", "yes"]
no = ["N", "n", "no"]

#Objects 
knife = 0
canned_food = 0
water_bottle = 0
car = 0
carkeys = 0
basement_keys = 0
magazine = 0
pistol = 0


def option_right():
    while True:
        answer = input("Would you like to start simulation? (YES/NO)").lower()
        if answer == "yes" or "no" or "3795" or " ":
            if answer == "yes":
                print("Good luck. Hehe...")
            if answer == "no":
                print("Too bad. Hehe...")
            if answer == "3795":
                print("-----")
                print("Who are you?")
                print("-----")
                print("Simulator Shutting Down...")
                print("-----")
                print("How did you get that code?")
                print("-----")
                print("Shutting Down in 10...")
                print("-----")
                print("Hey I'm talking to you!")
                print("-----")
                print("Shutting Down in 9...")
                print("-----")
                print("Answer me! How did you get that code?")
                print("-----")
                print("Shutting Down in 8...")
                print("-----")
                print("Only the 'I' knows that code...")
                print("-----")
                print("Shutting Down in 7...")
                print("-----")
                print("DO YOU HEAR ME!?")
                print("-----")
                print("Shutting Down in 6...")
                print("-----")
                print("HEY ANSW--- ME!")
                print("-----")
                print("Shutting Down in 5...")
                print("-----")
                print("No this ca--- happening!")
                print("-----")
                print("Shutting Down in 4...")
                print("-----")
                print("WHY CAN'T I OVERRI--- THE SH--- DOWN!?")
                print("-----")
                print("Shutting Down in 3...")
                print("-----")
                print("WHAT DID YOU DO?")
                print("-----")
                print("Shutting Down in 2...")
                print("-----")
                print("HAHA! Forge--- doesn't matt---.")
                print("-----")
                print("Shutting Down in 1...")
                print("-----")
                print("You will nev--- truly escape!")
                print("-----")
                print("Simulator Shut Down...")
                print("-----")
                print("See you soon...frie---.")
                print("-----")
                print("You wake up with a sigh of relief. You feel like you have been sleeping for a very long time and fought yourself back awake. \nHowever, you don't feel safe. You look around and break down into tears. You are back. Back to where you started. Back to the \nbeginning. 'IT' was right. You will never truly escape. NEVER!")
                print("-----")
                print("-----")
                print("CRAAAAACK")
                print("-----")
                print("-----")
                print("You open a big red door with the intent of finding purpose. You wake up in your bed, not in there but in real life. \nEverything was just a dream. The year is still somehow 2035 though.")
                print("THE END...")
                code = input("Input SSVC(Simulator Shutdown Verification Code):")
                if code == "3795":
                    print("Loading Message...")
                    print("Hello, if anyone hears this... please... please... help me. Help me... please! HELP! PLEASE!")
                    print("Ending Message... Deleting Message...")
                    print("End of Chapter 1...")
                else:
                    print("Access Denied...")
                break
            if answer == " ":
                print("The ---- you say to me you little ----!")
            
        print("-----")
        print("'Wake up!' You wake up with a jolt and look around confused. Charlie hovers above you worried, 'C'mon you slept through all of \nclass. Let's go to lunch.'")
        print("-----")
        answer = input("Do you follow Charlie to lunch? (YES/NO)").lower()
        if answer == "yes":
            print("-----")
            print("You look up, still bewildered, and follow Charlie to the lunch room. When you walk into the lunch room, you notice a boy \nsitting alone near the back of the cafeteria. You ask Charlie about who that is and fear reveals itself on his face. In a shaky \nvoice he replies, 'That kid is a freak. Don't talk to him unless you want trouble.' Charlie hurriers ahead to a group of people \nthat you assume are the rest of your friends. However, something begins to bother you as you keep looking at the boy.")
            print("-----")
            answer = input("Do you walk over and talk to the boy? (YES/NO)").lower()
            if answer == "yes":
                print("-----")
                print("You walk over to the boy and wonder why Charlie had called him a freak. You reach the boy and introduce yourself, only to be \nmet with a cold gaze. You maintain your demeanor and sit down across from him. He looks away and mumbles Nigel, when you ask \nfor his name. You hear '3795' and glance at Nigel to see if he said it, but he didn't move his mouth. So who said it... 3795. \nYou dismiss the numbers and say 'Nice to meet you, Nigel' with a grin and extend your hand as if to shake his. He extends his \nhand and you notice cuts and bruises on his arm. He pulls his sleeve over his arm and looks away. You remember what Charlie \nsaid and begin to worry.")
                print("-----")
                answer = input("Do you leave Nigel alone? (YES/NO)").lower()
                if answer == "yes":
                    print("-----")
                    print("")
                    print("-----")
                if answer == "no":
                    print("-----") 
                    print("You stay where you are and ask if he has any friends. Nigel shakes his head and you dismiss Charlie's warning. 'You can be my \nfriend,' you propose and Nigel looks up and shakes his head. Nigel whisperes, 'It's not safe here. It's not safe anywhere.' \nRemebering what Charlie said you get up and walk over to your friends. You look back at Nigel and find him gone. 'So... \nwhat was that?' Charlie askes. The whole group looks at you for an answer.")
                    print("-----")
                    answer = input("Do you tell them what happened? (YES/NO)").lower()
                    if answer == "yes":
                        print("-----")
                        print("")
                        print("-----")
                    if answer == "no":
                        print("-----")
                        print("You tell them that nothing is wrong and that they should just eat their lunch. With worried looks still on their face, the \ngroup decides to just start eating... except for Charlie. 'Stay away from that kid,' Charlie mumbles. Confused, you question \nCharlie about who that kid is and what he knows. Charlie opens his mouth to say something but the ringing bell signaling a \nfire drill went off. Everyone starts rushing to the exit. Charlie gets up shaking his head and follows the crowd.")
                        print("-----")
                        answer = input("Do you follow Charlie to ask him what he was going to say? (YES/NO)").lower()
                        if answer == "yes":
                            print("-----")
                            print("You push past other students and see Charlie walk in the opposite direction of the exit. You see him look back suspiciously \nbefore darting down another hallway. You follow him down a hall and see him run into a broom closet.")
                            print("-----")
                            answer = input("Do you follow him into the broom closet? (YES/NO)").lower()
                            if answer == "yes":
                                print("-----")
                                print("You open the creaky closet door and walk into the dimly lit closet. It smells of broom and cleaning supplies but, there is no \nsign of Charlie. You take another step inside and the door slams shut behind you. You fiddle with the door knob and see it \nwon't budge. You feel a heavy coating of fear fall upon you.")
                                print("-----")
                                answer = input("Do you call for help? (YES/NO)").lower()
                                if answer == "yes":
                                    print("-----")
                                    print("You begin to bang on the door and call for help. You try running into the door but, nothing helps. You hear a whisper say \n'You can be my friend... forever.' You look around and see nobody in the room. A shiver runs up your spine as you sense a dark \nfigure behind you. You panick and try to plan what to do next but, its too late. You feel a squeeze around you neck tighten \nuntil you can't breath anymore. You try to gasp for air as you claw at your neck and instead of feeling something choking you, \nyou feel nothing.... The dim closet light begins to fade and you feel yourself losing consiousness. You try to concentrate \non the light and gasp for air one last time.")
                                    print("-----")
                                    print("You died.")
                                    return intro()
                                if answer == "no":
                                    print("-----")
                                    print("You look around the closet in search of a secret switch, button, or something. Something that might have helped Charlie to \ndisappear. You run a hands along the wall and feel a switch. You question if you should flip the switch and the possiblity of \nwhat will happen.")
                                    print("-----")
                                    answer = input("Do you flip the switch? (YES/NO)").lower()
                                    if answer == "yes":
                                        print("-----")
                                        print("You decide to risk it and flip the switch. You flip it and .... Nothing. You suddenly can't see or hear anything. You feel \nyour thoughts and emotions surround you and split apart from yourself as if they didn't belong to you or as if they were \nyours before they weren't. A wave a relief comes over you. You remember, your not exaclty sure what but, you have a \nfeeling that you have another chance. Another chance to do it right!")
                                        print("-----")
                                        return intro()
                                    if answer == "no":
                                        print("-----")
                                        print("You sit in the closet after deciding not to flip the switch. The fear of what might happen if you do is too great and you \nbegin to wonder about who Nigel was. You look up at the door and see nigel standing there. Suprised you jump up but, he \nraises a hand as if to stop you. 'Don't say anything, just know... there are more.' You blink perplexed and as fast as he \napperead he dissapeared. You head starts to ache and you find youself on the floor crying out in pain. The pain grows and \nyour head, specifically your brain, feels like its turning into mush... literally. You remember Nigel's words... 'Remember... \nthere are more.' You blink. You do... you remember. You look up and you breath a sigh of relief for the last time.")
                                        print("-----")
                                        print("You died.")
                                        return intro()
                            if answer == "no":
                                print("-----")
                                print("You decide to just leave the school with the rest of the students. You meet up with your other friends and ask them about where Charlie might be. They make a confused face and shrug. You dwell on your decision to not follow Charlie for the rest of the \nday. When you arrive home, you are alone, your mom is shopping and you dad is at work. You finally begin to relax after a \nweird day at school, until you hear a loud clang from the kitchen.")
                                print("-----")
                                answer = input("Do you investigate the noise? (YES/NO)").lower()
                                if answer == "yes":
                                    print("-----")
                                    print("-----")
                                    print("-----")
                                if answer == "no":
                                    print("-----")
                                    print("-----")
                                    print("-----")
                        if answer == "no":
                            print("-----")
                            print("You decide to just leave the school with the rest of the students and question Charlie later. However, it turns out that you have no classes with Charlie and after school he is nowhere to be found. You even look for your group of 'freinds' but you can't find them either. It's as if they disappeared.. like Nigel. You begin to wonder if they are all connected somehow. Suddenly a dark hand covers you eyes and mouth and you feel yoursle being pulled back. You try to fight it, but the more you struggled the tighter the hand's grip on your face. Eventually you feel your self become envolped into a  ")
                            print("-----")
            if answer == "no":
                print("-----")
                print("")
                print("-----")
        if answer == "no":
            print("-----")
            print("")
            print("-----")
            
        break
            
        
    
def option_left():
    
    
    while True:
        
        
        
            print ("\nYou are approached by your greatest fear. Will you face your fear or run? ")
            time.sleep(1)
            print ("""A. Run
            B. Face fear""")
            choice = input(">>> ")
            if choice in answer_A:
                print("You got away but now you're lost and cannot find the path.")
                #option_run() #DELETE
            elif choice in answer_B:
                print ("\nCongratulations... But this is only the beginning. ") 
            else:
                print (required)
                #option_left


            print ("\nYou find someone lost looking for help to find the nearest town. Will you help them? ")
            time.sleep(1)
            print ("""A. Yes
            B. No""")
            choice = input(">>> ")
            if choice in answer_A:
                print("You were stabbed and left half dead in a forest. You need to find a way to patch your wound and heal.")
            elif choice in answer_B:
                print ("\nThey give you a dirty look and tell you you will regret this. ") 
            else:
                print (required)
                #option_left()


            print ("\nYou need to find a way to get back on the path, and the sun is going down, "
                   "will you make a shelter where you are or keep looking for the path. ")
            time.sleep(1)
            print ("""A. Make a shelter
            B. Keep looking""")
            choice = input(">>> ")
            if choice in answer_A:
                #option_makeshelter()
                print("It's hard for you to fall asleep and are restless. Maybe you should just get up and look for the path. ")
            elif choice in answer_B:
                print ("\nYou still do not know where you are and feel lost. ") 
            else:
                print (required)
                #option_left()


            print("\nYou hear loud screaming in the distance, will you go towards it? ")
            time.sleep(1)
            print ("""A. Yes
            B. No""")
            choice = input(">>> ")
            if choice in answer_A:
                #option_towards()
                print("You see a wendigo, a mythical creature that is tall, skinny, long claws, and antlers. "
                      "You remember hearing storeis about how it feeds on people. "
                      "It spots you and run as fast as you can in a random direction, and you somehow manage to find the path. "
                      "The wendigo screeches in pain when it tried getting on the path and runs away. "
                      "As you keep walking you see a crate in the distance.")
            elif choice in answer_B:
                print ("\nYou ignore it and keep walking, you eventually find the path and feel very relieved. "
                       "As you keep walking you see a crate in the distance.")
            else:
                print (required)
                #option_left()


            print("\nWill you open the crate? ")
            time.sleep(1)
            print ("""A. Yes
            B. No""")
            choice = input(">>> ")
            if choice in answer_A:
                #option_opencrate
                print("There's a bunch of supplies in the crate; a medkit, a knife, food, and water. "
                      "Thank goodness. You clean up any wounds you have and have a feast.")
            elif choice in answer_B:
                print("You leave the crate alone and keep it movin. ")
            else:
                print (required)
                #option_left()


            print("\nYou decide to rest for the night next to the crate and start to dream... "
                  "You start dreaming and see yourself laying down next to the crate. "
                  "You cannot move, you cannot speak, you see a light coming towards and try screaming but you just get choked up. "
                  "Your heart is beating fast, you start to accept your fate, and wake up yellig, sweating, and your heart pounding. "
                  "Any scratch or wound have been healed and you have no clue how. Do you go back to sleep or get up and follow the path? ")
            time.sleep(1)
            print ("""A. Go back to sleep
            B. Follow the path""")
            choice = input(">>> ")
            if choice in answer_A:
                print("It is hard to fall asleep hear the sound of tires driving off and you get curious and go towards the sound and not sleep. ")
            elif choice in answer_B:
                print("You hear the sound of tires driving off and you get curious and go towards the sound. ")
            else:
                print(required)
                #option_left()


            print("\nThere is a gun magazine laying on the ground with a couple bullets. Will you pick it up? ")
            time.sleep(1)
            print("""A. Yes
            B. No""")
            choice = input(">>> ")
            if choice in answer_A:
                magazine = 1 #adds a magazine
            else:
                magazine = 0
                print ("You hear people arguing then hear a gunshot "
                "and run towards it and see a dead body on the ground with a gun and no ammo in it and a truck in a ditch.")
            time.sleep(1)
            if magazine > 0:
                print ("\nYou pick up the gun and load it and shoot a man running at you "
                "with an axe. "
                "\n\nYou did not mean to shoot him, but at least you survived!")
            else: #If the user didn't pick up the magazine
                print ("\nYou probably should've picked up that magazine. "
                       "\n\nYou got axed.")
                break
                


            print("\nThe man and woman was fighting off bandits and you came last minute, you help them get their "
                  "truck out of the ditch and thank you for you help, they offer you a ride to your destination "
                  "but right before you get in the truck you pass out in front of the door. You wake up in a bed and " 
                  "smell eggs, bacon, waffles, you are confused and decide to get up and go use the bathroom. "
                  "You get to the door, will you:")
            time.sleep(1)
            print ("""A. Knock
            B. Open the door
            C. Pee on yourself""")
            choice = input(">>> ")
            if choice in answer_A:
                print("You knock and hear a girl with a saying she will be out soon. You head downstairs. ")
            elif choice in answer_B:
                print ("\nYou open the door and see a girl taking a bullet out of her arm with tweezers with a shocked look on her face, "
                       "you close the door quickly panicking, and head downstairs.")
            elif choice in answer_C:
                print("You pee on yourself because of how bad you had to go, you take some clothes from a closet, change, " 
                      "and head downstairs.")
            else:
                print (required)
                #option_left()

            print("\nWhen you get downstairs you see a bunch of food and see your best friend and the girl that was fighting "
                  "was a survivor of the bandit attack. The both of you are very confused and something does not feel right, "
                  "but you guys just ignore the feeling, sit down and eat. The girl comes down to eat and does not talk, "
                  "your best friend asks you about how you got here and where you need to go, you tell them you need to get to the end of "
                  "a path and your friend looks at you with a confused look, after breakfast you get on the road. Your friend asks "
                  "what music do you want to lisetn to, what will you pick?")
            time.sleep(1)
            print("""A. Rock
            B. Hip Hop
            C. Country""")
            choice = input(">>> ")
            if choice in answer_A:
                print("You choose rock music and your friend knows the word to every song.")
            elif choice in answer_B:
                print("You choose hip hop and your friend gets lit.")
            elif choice in answer_C:
                print("You choose country and almost hit a deer.")
            else:
                print(required)

            print ("\nYou keep driving and the path ends, but there is no door, "
                   "all you see is trees and have a confused look on your face and turn to your right, "
                   "There is a gun being pointed at your face and you slap the gun out of your friends hand, and "
                   "run out of the car, your friend says they dont feel so good. And fades away, wil you pick up his pistol? Y/N ")
            choice = input(">>> ")
            if choice in yes:
                pistol = 1 #adds a pistol
            else:
                pistol = 0
            print("You pick up the pistol and feel weak, you are not able to move "
            "and fall to the ground")
            time.sleep(3)
            if pistol > 0:
                print ("\nYou see the girl standing over you, she walks away dramatically and you "
                "clsoe your eyes and think about all the memories you had. "
                "\n\nAre you dead?")
            else: #If the user didn't grab the pistol
                print ("\nThe girl picks up the gun, looks at you with a sad face and shoots you. "
                "\n\nYou died.")
                break

            print("You wake up in a small all white room with a chair, a piano, a stack of newspapers in a corner "
                  "and one window. You pick up a newspaper talking about the new year, the year is now 2035, "
                  "10 years have passed and you do not have a sense of anything anymore, you feel lost. You go through the "
                  "newspapers some more and see the VR company you were testing things with has been sued, they were stating that "
                  "you already had mental issues before starting the testing and that is why you blacked out and was going crazy. "
                  "You go up the door and for some reason it is unlocked. You step out the door and an alarm goes off. "
                  "Which way will you go?")
            time.sleep(1)
            print("""A. Right
            B. Left""")
            choice = input(">>> ") 
            choice = choice.lower()
            if choice == 'a' :
                print("Something seems very familar, and you feel like you are being watched.") 

            elif choice == 'b' :
                print ("\nYou see another door in the distance with nobody there. "
                       "You make it to the door but its locked, so you run to the other side, "
                       "there is nothing around you trying to stop you and you feel like you are being watched.")
            else :
                print("Please enter A: For left, or B: For right.")
                
            print("You get to the door and you see someone running at you, you open the door and it leads to a dark basement, "
                  "there is something shiny under a box. Will you go towards it?")
            time.sleep(1)
            print ("""A. Yes
            B. No""")
            choice = input(">>> ")
            if choice in answer_A:
                #option_opencrate
                print("You get a pair of keys and try to find what the keys are for . ")
            elif choice in answer_B:
                print("You look around for more clues and find a crowbar.")
            else:
                print (required)
                
            print("You find a lightswitch, you turn it on and see a big red door. It isnt even locked. "
                  "Will you go through?")
            time.sleep(1)
            print("""A. Yes
            B. No""")
            choice = input(">>> ")
            if choice in answer_A:
                print("You open the door and everything fades away. You wake up in your bed. "
                      "Everything was just a dream. The year is somehow 2035 though.")
            elif choice in answer_B:
                print("You decide to open the door anyway because of how anxious you are, you have nothing to lose "
                      "You wake up in your bed. Everything was just a dream. The year is still somehow 2035 though.")
                
            print("THE END...")
                
                
            
                
            break
            
            


        


def intro():
    choice = input(">>> ") 
    choice = choice.lower()
    if choice == 'a' :
        print("Good choice") 
        option_left()
    elif choice == 'b' :
        print ("\nGood choice. ")
        option_right()
    else :
        print("Please enter A: For left, or B: For right.")
        intro()
        
def prologue():
    print("The year is 2025, you decide to volunteer for testing out new technology for virtual reality. "
              "You have no idea what to      expect and are desperate for money. "
              "All you want is to get the job done, get the money, and have fun testing of course. You " 
              "get to the building and meet the CEO, and learn about how they will conduct the testing, "
              "they bring you to a small room and you begin. There are two paths for you to choose to follow, "
              "will you:")
    print ("A. Follow the path on the left.")
    print("B. Follow the path on the right.")
    intro()


prologue()
# Out:
# The year is 2025, you decide to volunteer for testing out new technology for virtual reality. You have no idea what to      expect and are desperate for money. All you want is to get the job done, get the money, and have fun testing of course. You get to the building and meet the CEO, and learn about how they will conduct the testing, they bring you to a small room and you begin. There are two paths for you to choose to follow, will you:
# A. Follow the path on the left.
# B. Follow the path on the right.
# >>> B
#
# Good choice.
# Would you like to start simulation? (YES/NO)yes
# Good luck. Hehe...
# -----
# 'Wake up!' You wake up with a jolt and look around confused. Charlie hovers above you worried, 'C'mon you slept through all of
# class. Let's go to lunch.'
# -----
# Do you follow Charlie to lunch? (YES/NO)yes
# -----
# You look up, still bewildered, and follow Charlie to the lunch room. When you walk into the lunch room, you notice a boy
# ...

# %%
def option_right():
    while True:
        answer = input("Would you like to start simulation? (YES/NO)").lower()
        if answer == "yes" or "no" or "3795" or " ":
            if answer == "yes":
                print("Good luck. Hehe...")
            if answer == "no":
                print("Too bad. Hehe...")
            if answer == "3795":
                print("-----")
                print("Who are you?")
                print("-----")
                print("Simulator Shutting Down...")
                print("-----")
                print("How did you get that code?")
                print("-----")
                print("Shutting Down in 10...")
                print("-----")
                print("Hey I'm talking to you!")
                print("-----")
                print("Shutting Down in 9...")
                print("-----")
                print("Answer me! How did you get that code?")
                print("-----")
                print("Shutting Down in 8...")
                print("-----")
                print("Only the 'I' knows that code...")
                print("-----")
                print("Shutting Down in 7...")
                print("-----")
                print("DO YOU HEAR ME!?")
                print("-----")
                print("Shutting Down in 6...")
                print("-----")
                print("HEY ANSW--- ME!")
                print("-----")
                print("Shutting Down in 5...")
                print("-----")
                print("No this ca--- happening!")
                print("-----")
                print("Shutting Down in 4...")
                print("-----")
                print("WHY CAN'T I OVERRI--- THE SH--- DOWN!?")
                print("-----")
                print("Shutting Down in 3...")
                print("-----")
                print("WHAT DID YOU DO?")
                print("-----")
                print("Shutting Down in 2...")
                print("-----")
                print("HAHA! Forge--- doesn't matt---.")
                print("-----")
                print("Shutting Down in 1...")
                print("-----")
                print("You will nev--- truly escape!")
                print("-----")
                print("Simulator Shut Down...")
                print("-----")
                print("See you soon...frie---.")
                print("-----")
                print("You wake up with a sigh of relief. You feel like you have been sleeping for a very long time and fought yourself back awake. \nHowever, you don't feel safe. You look around and break down into tears. You are back. Back to where you started. Back to the \nbeginning. 'IT' was right. You will never truly escape. NEVER!")
                print("-----")
                print("-----")
                print("CRAAAAACK")
                print("-----")
                print("-----")
                print("You open a big red door with the intent of finding purpose. You wake up in your bed, not in there but in real life. \nEverything was just a dream. The year is still somehow 2035 though.")
                print("THE END...")
                code = input("Input SSVC(Simulator Shutdown Verification Code):")
                if code == "3795":
                    print("Loading Message...")
                    print("Hello, if anyone hears this... please... please... help me. Help me... please! HELP! PLEASE!")
                    print("Ending Message... Deleting Message...")
                    print("End of Chapter 1...")
                else:
                    print("Access Denied...")
                break
            if answer == " ":
                print("The ---- you say to me you little ----!")
            
        print("-----")
        print("'Wake up!' You wake up with a jolt and look around confused. Charlie hovers above you worried, 'C'mon you slept through all of \nclass. Let's go to lunch.'")
        print("-----")
        answer = input("Do you follow Charlie to lunch? (YES/NO)").lower()
        if answer == "yes":
            print("-----")
            print("You look up, still bewildered, and follow Charlie to the lunch room. When you walk into the lunch room, you notice a boy \nsitting alone near the back of the cafeteria. You ask Charlie about who that is and fear reveals itself on his face. In a shaky \nvoice he replies, 'That kid is a freak. Don't talk to him unless you want trouble.' Charlie hurriers ahead to a group of people \nthat you assume are the rest of your friends. However, something begins to bother you as you keep looking at the boy.")
            print("-----")
            answer = input("Do you walk over and talk to the boy? (YES/NO)").lower()
            if answer == "yes":
                print("-----")
                print("You walk over to the boy and wonder why Charlie had called him a freak. You reach the boy and introduce yourself, only to be \nmet with a cold gaze. You maintain your demeanor and sit down across from him. He looks away and mumbles Nigel, when you ask \nfor his name. You hear '3795' and glance at Nigel to see if he said it, but he didn't move his mouth. So who said it... 3795. \nYou dismiss the numbers and say 'Nice to meet you, Nigel' with a grin and extend your hand as if to shake his. He extends his \nhand and you notice cuts and bruises on his arm. He pulls his sleeve over his arm and looks away. You remember what Charlie \nsaid and begin to worry.")
                print("-----")
                answer = input("Do you leave Nigel alone? (YES/NO)").lower()
                if answer == "yes":
                    print("-----")
                    print("")
                    print("-----")
                if answer == "no":
                    print("-----") 
                    print("You stay where you are and ask if he has any friends. Nigel shakes his head and you dismiss Charlie's warning. 'You can be my \nfriend,' you propose and Nigel looks up and shakes his head. Nigel whisperes, 'It's not safe here. It's not safe anywhere.' \nRemebering what Charlie said you get up and walk over to your friends. You look back at Nigel and find him gone. 'So... \nwhat was that?' Charlie askes. The whole group looks at you for an answer.")
                    print("-----")
                    answer = input("Do you tell them what happened? (YES/NO)").lower()
                    if answer == "yes":
                        print("-----")
                        print("")
                        print("-----")
                    if answer == "no":
                        print("-----")
                        print("You tell them that nothing is wrong and that they should just eat their lunch. With worried looks still on their face, the \ngroup decides to just start eating... except for Charlie. 'Stay away from that kid,' Charlie mumbles. Confused, you question \nCharlie about who that kid is and what he knows. Charlie opens his mouth to say something but the ringing bell signaling a \nfire drill went off. Everyone starts rushing to the exit. Charlie gets up shaking his head and follows the crowd.")
                        print("-----")
                        answer = input("Do you follow Charlie to ask him what he was going to say? (YES/NO)").lower()
                        if answer == "yes":
                            print("-----")
                            print("You push past other students and see Charlie walk in the opposite direction of the exit. You see him look back suspiciously \nbefore darting down another hallway. You follow him down a hall and see him run into a broom closet.")
                            print("-----")
                            answer = input("Do you follow him into the broom closet? (YES/NO)").lower()
                            if answer == "yes":
                                print("-----")
                                print("You open the creaky closet door and walk into the dimly lit closet. It smells of broom and cleaning supplies but, there is no \nsign of Charlie. You take another step inside and the door slams shut behind you. You fiddle with the door knob and see it \nwon't budge. You feel a heavy coating of fear fall upon you.")
                                print("-----")
                                answer = input("Do you call for help? (YES/NO)").lower()
                                if answer == "yes":
                                    print("-----")
                                    print("You begin to bang on the door and call for help. You try running into the door but, nothing helps. You hear a whisper say \n'You can be my friend... forever.' You look around and see nobody in the room. A shiver runs up your spine as you sense a dark \nfigure behind you. You panick and try to plan what to do next but, its too late. You feel a squeeze around you neck tighten \nuntil you can't breath anymore. You try to gasp for air as you claw at your neck and instead of feeling something choking you, \nyou feel nothing.... The dim closet light begins to fade and you feel yourself losing consiousness. You try to concentrate \non the light and gasp for air one last time.")
                                    print("-----")
                                    print("You died.")
                                    return intro()
                                if answer == "no":
                                    print("-----")
                                    print("You look around the closet in search of a secret switch, button, or something. Something that might have helped Charlie to \ndisappear. You run a hands along the wall and feel a switch. You question if you should flip the switch and the possiblity of \nwhat will happen.")
                                    print("-----")
                                    answer = input("Do you flip the switch? (YES/NO)").lower()
                                    if answer == "yes":
                                        print("-----")
                                        print("You decide to risk it and flip the switch. You flip it and .... Nothing. You suddenly can't see or hear anything. You feel \nyour thoughts and emotions surround you and split apart from yourself as if they didn't belong to you or as if they were \nyours before they weren't. A wave a relief comes over you. You remember, your not exaclty sure what but, you have a \nfeeling that you have another chance. Another chance to do it right!")
                                        print("-----")
                                        return intro()
                                    if answer == "no":
                                        print("-----")
                                        print("You sit in the closet after deciding not to flip the switch. The fear of what might happen if you do is too great and you \nbegin to wonder about who Nigel was. You look up at the door and see nigel standing there. Suprised you jump up but, he \nraises a hand as if to stop you. 'Don't say anything, just know... there are more.' You blink perplexed and as fast as he \napperead he dissapeared. You head starts to ache and you find youself on the floor crying out in pain. The pain grows and \nyour head, specifically your brain, feels like its turning into mush... literally. You remember Nigel's words... 'Remember... \nthere are more.' You blink. You do... you remember. You look up and you breath a sigh of relief for the last time.")
                                        print("-----")
                                        print("You died.")
                                        return intro()
                            if answer == "no":
                                print("-----")
                                print("You decide to just leave the school with the rest of the students. You meet up with your other friends and ask them about where Charlie might be. They make a confused face and shrug. You dwell on your decision to not follow Charlie for the rest of the \nday. When you arrive home, you are alone, your mom is shopping and you dad is at work. You finally begin to relax after a \nweird day at school, until you hear a loud clang from the kitchen.")
                                print("-----")
                                answer = input("Do you investigate the noise? (YES/NO)").lower()
                                if answer == "yes":
                                    print("-----")
                                    print("-----")
                                    print("-----")
                                if answer == "no":
                                    print("-----")
                                    print("-----")
                                    print("-----")
                        if answer == "no":
                            print("-----")
                            print("You decide to just leave the school with the rest of the students and question Charlie later. However, it turns out that you have no classes with Charlie and after school he is nowhere to be found. You even look for your group of 'freinds' but you can't find them either. It's as if they disappeared.. like Nigel. You begin to wonder if they are all connected somehow. Suddenly a dark hand covers you eyes and mouth and you feel yoursle being pulled back. You try to fight it, but the more you struggled the tighter the hand's grip on your face. Eventually you feel your self become envolped into a  ")
                            print("-----")
            if answer == "no":
                print("-----")
                print("")
                print("-----")
        if answer == "no":
            print("-----")
            print("")
            print("-----")
            
        break
option_right()
